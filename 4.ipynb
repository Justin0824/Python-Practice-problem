# %% [markdown]
# lst=["MK",2,True,4,5,4]
# print(type(lst))
# print(lst[0])
# print(lst[2:5])
# l1=list()
# print(type(l1))
# lst

# %%
l1=[1,"MK",2.5,True,100]
print(l1)
print(type(l1))
print(l1[4])
print(l1[0])
print(l1[-1])
print(l1[2:5])
print(l1[0:6:2])
l1[: :]
print(l1[2: :])
print(l1[:5 :])
print(l1[ : :-1])
print(l1[6:1])
print(len(l1))
l1.append(5)
# Out:
# [1, 'MK', 2.5, True, 100]
# <class 'list'>
# 100
# 1
# 100
# [2.5, True, 100]
# [1, 2.5, 100]
# [2.5, True, 100]
# [1, 'MK', 2.5, True, 100]
# [100, True, 2.5, 'MK', 1]
# []

# %%
l1=[1,"MK",2.5,True,100]
l2=[]
l1.append(5)
l1.insert(4,70)

print(l1)
l1[4]=2
print(l1)
l1.insert(4,[70,10,5])
l1
# Out:
# [1, 'MK', 2.5, True, 70, 100, 5]
# [1, 'MK', 2.5, True, 2, 100, 5]
# [1, 'MK', 2.5, True, [70, 10, 5], 2, 100, 5]

# %%
l1=[1, 'MK', 2.5, True, [70, 10, 5], 2, 100, 5]
l2=["mk",5]
#l2.extend(l1)


l2.extend([70])
print(l2)
# Out:
# ['mk', 5, 70]

# %%
l1=[1, 'MK', 2.5, True, [70, 10, 5], 2, 100, 5]
l2=["mk",5]
#l2.extend(l1)


l2.extend([5,[4,3]])
print(l2)
''' l1.pop()

l1.pop(5)


l2.remove(5)
print(l2)
del l1[2]
print(l1)
del l2
'''
# Out:
# ['mk', 5, 5, [4, 3]]
# ' l1.pop()\n\nl1.pop(5)\n\n\nl2.remove(5)\nprint(l2)\ndel l1[2]\nprint(l1)\ndel l2\n'

# %%
lst1=[1,2,3,4]
lst2=[5,6,7,8]
lst1=lst1[::-1]
print(lst1)

lst1.append(lst2)
lst1
# Out:
# [4, 3, 2, 1]
# [4, 3, 2, 1, [5, 6, 7, 8]]

# %%
lst1=[1,2,3,4]
l2=[]
for i in range(len(lst1)-1,-1,-1):
    l2.append(lst1[i])

l2
# Out:
# [4, 3, 2, 1]
